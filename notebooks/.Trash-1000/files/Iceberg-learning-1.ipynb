# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col,split,explode,size
from pyspark.sql import functions as F
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, DoubleType

spark = (
    SparkSession.builder
    .appName("iceberg-learning")
    .master("local[*]")
    .config(
        "spark.jars.packages",
        "org.apache.iceberg:iceberg-spark-runtime-3.5_2.12:1.5.2"
    )
    .config(
        "spark.sql.extensions",
        "org.apache.iceberg.spark.extensions.IcebergSparkSessionExtensions"
    )
    .config(
        "spark.sql.catalog.local",
        "org.apache.iceberg.spark.SparkCatalog"
    )
    .config(
        "spark.sql.catalog.local.type",
        "hadoop"
    )
    .config(
        "spark.sql.catalog.local.warehouse",
        "/data/warehouse"
    )
    .getOrCreate()
)

df = spark.read.parquet("/data/raw/machine-raw-log.snappy.parquet")

# %%
df.columns
# Out:
# ['SequenceNumber',
#  'DTFolder',
#  'Mid',
#  'LogId',
#  'AZ_BATCH_ID',
#  'CellValue',
#  'Cell',
#  'CreationDateTime',
#  'raw_ingesttime',
#  'enriched_ingesttime',
#  'Timestamp',
#  'LogicalID',
#  'BODID',
#  'ChassisId',
#  'PIN17',
#  'VIN',
#  'SalesModel',
#  'SerialNumber',
#  'ServiceBus_MessageID']

# %%
df.show()
# Out:
# +--------------+--------------+---+-----+-----------+---------+----+--------------------+--------------------+--------------------+-------------------+---------+--------------------+-----------+-----+-----------------+----------+------------+--------------------+
# |SequenceNumber|      DTFolder|Mid|LogId|AZ_BATCH_ID|CellValue|Cell|    CreationDateTime|      raw_ingesttime| enriched_ingesttime|          Timestamp|LogicalID|               BODID|  ChassisId|PIN17|              VIN|SalesModel|SerialNumber|ServiceBus_MessageID|
# +--------------+--------------+---+-----+-----------+---------+----+--------------------+--------------------+--------------------+-------------------+---------+--------------------+-----------+-----+-----------------+----------+------------+--------------------+
# |             0|20210525155439|  0| 1061|   10000376|  2083007|   1|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|29f96ff4-a8a0-427...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0| 1061|   10000376|      577|   2|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|29f96ff4-a8a0-427...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0| 1061|   10000376|      598|   3|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|29f96ff4-a8a0-427...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0| 1061|   10000376|        0|   4|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|29f96ff4-a8a0-427...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0| 1061|   10000376|   536585|   5|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|29f96ff4-a8a0-427...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0| 1061|   10000376|        0|   6|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|29f96ff4-a8a0-427...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0| 1061|   10000376|      960|   7|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|29f96ff4-a8a0-427...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  324|   10000376|  2083005|   1|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|e1125acb-c515-470...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  324|   10000376|   569190|   2|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|e1125acb-c515-470...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  324|   10000376|   141905|   3|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|e1125acb-c515-470...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  324|   10000376|   603270|   4|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|e1125acb-c515-470...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  420|   10000376|  2083006|   1|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|d430e27a-00e9-486...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  420|   10000376|        0|   2|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|d430e27a-00e9-486...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  420|   10000376|        0|   3|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|d430e27a-00e9-486...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  420|   10000376|    68833|   4|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|d430e27a-00e9-486...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  420|   10000376|  1479726|   5|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|d430e27a-00e9-486...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  420|   10000376|   155733|   6|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|d430e27a-00e9-486...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  420|   10000376|    22674|   7|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|d430e27a-00e9-486...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  420|   10000376|    36280|   8|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|d430e27a-00e9-486...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# |             0|20210525155439|  0|  420|   10000376|    31045|   9|2021-05-24 15:33:...|2021-05-25 13:54:...|2021-05-25 13:55:...|1970-01-01 00:00:00|    arigw|d430e27a-00e9-486...|H100E121013|     |VCEH100ETL0121013|          |            |                   0|
# +--------------+--------------+---+-----+-----------+---------+----+--------------------+--------------------+--------------------+-------------------+---------+--------------------+-----------+-----+-----------------+----------+------------+--------------------+
# only showing top 20 rows

# %%
mapping_schema = StructType([
    StructField("PIPELINE", StringType(), True),
    StructField("LOG_ID", IntegerType(), True),
    StructField("Cell", StringType(), True),
    StructField("MEASURE_CODE_ACC", StringType(), True),
    StructField("UNIT", DoubleType(), True),
    StructField("TARGET_UNIT", StringType(), True),
    StructField("DESCRIPTION", StringType(), True)
])

df_mapping = spark.read.option("header", "true").schema(mapping_schema).csv("/data/raw/log_cell_mapping.csv")

# %%
df_mapping = df_mapping.withColumn("Cell_Array",split(df_mapping['Cell'],",")).withColumn("Cell_number",explode("Cell_Array")).withColumn("Cell_Count",size(col("Cell_Array")))

# %%
df_mapping.show()
# Out:
# +------------+------+----+--------------------+-----+-----------+--------------------+----------+-----------+----------+
# |    PIPELINE|LOG_ID|Cell|    MEASURE_CODE_ACC| UNIT|TARGET_UNIT|         DESCRIPTION|Cell_Array|Cell_number|Cell_Count|
# +------------+------+----+--------------------+-----+-----------+--------------------+----------+-----------+----------+
# |      HAULER|  1061|   1|     ENG_HOURS_TOTAL| 0.05|      Hours|Total cumulative ...|       [1]|          1|         1|
# |      HAULER|  1061| 1,2|     TOTAL_FUEL_USED|0.001|     Liters|Cumulative engine...|    [1, 2]|          1|         2|
# |      HAULER|  1061| 1,2|     TOTAL_FUEL_USED|0.001|     Liters|Cumulative engine...|    [1, 2]|          2|         2|
# |      HAULER|  1080|   3|    IDLE_HOURS_TOTAL|  0.1|      Hours|Total engine idle...|       [3]|          3|         1|
# |      HAULER|  1080| 4,5|      IDLE_FUEL_USED|0.001|     Liters|Total fuel consum...|    [4, 5]|          4|         2|
# |      HAULER|  1080| 4,5|      IDLE_FUEL_USED|0.001|     Liters|Total fuel consum...|    [4, 5]|          5|         2|
# |      HAULER|  1100|   1| PAYLOAD_WEIGHT_TONS| 0.01|Metric Tons|Accumulated paylo...|       [1]|          1|         1|
# |      HAULER|  1100|   2|   HAUL_CYCLES_COUNT|  1.0|      Count|Total completed h...|       [2]|          2|         1|
# |   EXCAVATOR|  2040|   1|  TRAVEL_DISTANCE_KM|0.001| Kilometers|Odometer accumula...|       [1]|          1|         1|
# |   EXCAVATOR|  2040| 2,3| DEF_CONSUMED_LITERS|0.001|     Liters|Diesel Exhaust Fl...|    [2, 3]|          2|         2|
# |   EXCAVATOR|  2040| 2,3| DEF_CONSUMED_LITERS|0.001|     Liters|Diesel Exhaust Fl...|    [2, 3]|          3|         2|
# |   EXCAVATOR|  2055|   1|   SWING_HOURS_TOTAL|  0.1|      Hours|Total upper struc...|       [1]|          1|         1|
# |   EXCAVATOR|  2055|   2|  HAMMER_HOURS_TOTAL|  0.1|      Hours|Total hydraulic b...|       [2]|          2|         1|
# |WHEEL_LOADER|  3010|   1|     ENG_HOURS_TOTAL| 0.05|      Hours|Total engine oper...|       [1]|          1|         1|
# |WHEEL_LOADER|  3010|   4|  HYDRAULIC_WORK_HRS|  0.1|      Hours|Hydraulic system ...|       [4]|          4|         1|
# |WHEEL_LOADER|  3020| 1,2|  BUCKET_LOADS_COUNT|  1.0|      Count|Total bucket load...|    [1, 2]|          1|         2|
# |WHEEL_LOADER|  3020| 1,2|  BUCKET_LOADS_COUNT|  1.0|      Count|Total bucket load...|    [1, 2]|          2|         2|
# |WHEEL_LOADER|  3020|   3|REVERSE_TRAVEL_HOURS|  0.1|      Hours|Total hours drive...|       [3]|          3|         1|
# |     GENERAL|  1001|   1|     GPS_DISTANCE_KM| 0.01| Kilometers|GPS accumulated t...|       [1]|          1|         1|
# |     GENERAL|  1001|   2|    CO2_EMISSIONS_KG|  0.1|  Kilograms|Estimated cumulat...|       [2]|          2|         1|
# +------------+------+----+--------------------+-----+-----------+--------------------+----------+-----------+----------+

# %%
lkpDF = df_mapping.select("MEASURE_CODE_ACC","LOG_ID","Cell_number","UNIT","Cell_Array","Cell_Count","PIPELINE")
cond = [((df.LogId == lkpDF.LOG_ID) &\
         (df.Cell == lkpDF.Cell_number))]
mergedDF = df.join(lkpDF,on = cond, how = "inner" )
mergedDF = mergedDF.withColumn("CellValue_new",col("CellValue")*col("UNIT"))

# %%
mergedDF.show()
# Out:
# +-----------+----+-----+---------+--------------------+----------------+------+-----------+-----+----------+----------+--------+------------------+
# |  ChassisId|Cell|LogId|CellValue|    CreationDateTime|MEASURE_CODE_ACC|LOG_ID|Cell_number| UNIT|Cell_Array|Cell_Count|PIPELINE|     CellValue_new|
# +-----------+----+-----+---------+--------------------+----------------+------+-----------+-----+----------+----------+--------+------------------+
# |H100E121013|   1| 1061|  2083007|2021-05-24 15:33:...| TOTAL_FUEL_USED|  1061|          1|0.001|    [1, 2]|         2|  HAULER|          2083.007|
# |H100E121013|   1| 1061|  2083007|2021-05-24 15:33:...| ENG_HOURS_TOTAL|  1061|          1| 0.05|       [1]|         1|  HAULER|         104150.35|
# |H100E121013|   2| 1061|      577|2021-05-24 15:33:...| TOTAL_FUEL_USED|  1061|          2|0.001|    [1, 2]|         2|  HAULER|             0.577|
# |H100E121015|   1| 1061|  2336943|2021-05-24 15:43:...| TOTAL_FUEL_USED|  1061|          1|0.001|    [1, 2]|         2|  HAULER|          2336.943|
# |H100E121015|   1| 1061|  2336943|2021-05-24 15:43:...| ENG_HOURS_TOTAL|  1061|          1| 0.05|       [1]|         1|  HAULER|116847.15000000001|
# |H100E121015|   2| 1061|      843|2021-05-24 15:43:...| TOTAL_FUEL_USED|  1061|          2|0.001|    [1, 2]|         2|  HAULER|             0.843|
# |H100E121013|   1| 1061|  2084807|2021-05-24 16:03:...| TOTAL_FUEL_USED|  1061|          1|0.001|    [1, 2]|         2|  HAULER|2084.8070000000002|
# |H100E121013|   1| 1061|  2084807|2021-05-24 16:03:...| ENG_HOURS_TOTAL|  1061|          1| 0.05|       [1]|         1|  HAULER|         104240.35|
# |H100E121013|   2| 1061|      577|2021-05-24 16:03:...| TOTAL_FUEL_USED|  1061|          2|0.001|    [1, 2]|         2|  HAULER|             0.577|
# |H100E121015|   1| 1061|  2338744|2021-05-24 16:13:...| TOTAL_FUEL_USED|  1061|          1|0.001|    [1, 2]|         2|  HAULER|          2338.744|
# |H100E121015|   1| 1061|  2338744|2021-05-24 16:13:...| ENG_HOURS_TOTAL|  1061|          1| 0.05|       [1]|         1|  HAULER|116937.20000000001|
# |H100E121015|   2| 1061|      844|2021-05-24 16:13:...| TOTAL_FUEL_USED|  1061|          2|0.001|    [1, 2]|         2|  HAULER|             0.844|
# |H100E121013|   1| 1061|  2086608|2021-05-24 16:33:...| TOTAL_FUEL_USED|  1061|          1|0.001|    [1, 2]|         2|  HAULER|          2086.608|
# |H100E121013|   1| 1061|  2086608|2021-05-24 16:33:...| ENG_HOURS_TOTAL|  1061|          1| 0.05|       [1]|         1|  HAULER|104330.40000000001|
# |H100E121013|   2| 1061|      578|2021-05-24 16:33:...| TOTAL_FUEL_USED|  1061|          2|0.001|    [1, 2]|         2|  HAULER|             0.578|
# |H100E121015|   1| 1061|  2340542|2021-05-24 16:43:...| TOTAL_FUEL_USED|  1061|          1|0.001|    [1, 2]|         2|  HAULER|          2340.542|
# |H100E121015|   1| 1061|  2340542|2021-05-24 16:43:...| ENG_HOURS_TOTAL|  1061|          1| 0.05|       [1]|         1|  HAULER|          117027.1|
# |H100E121015|   2| 1061|      844|2021-05-24 16:43:...| TOTAL_FUEL_USED|  1061|          2|0.001|    [1, 2]|         2|  HAULER|             0.844|
# | A40G341022|   1| 1061|  2676101|2021-05-24 16:59:...| TOTAL_FUEL_USED|  1061|          1|0.001|    [1, 2]|         2|  HAULER|          2676.101|
# | A40G341022|   1| 1061|  2676101|2021-05-24 16:59:...| ENG_HOURS_TOTAL|  1061|          1| 0.05|       [1]|         1|  HAULER|133805.05000000002|
# +-----------+----+-----+---------+--------------------+----------------+------+-----------+-----+----------+----------+--------+------------------+
# only showing top 20 rows

# %%
groupbyCols = [
    "ChassisId",
    "CreationDateTime",
    "LogId",
    "MEASURE_CODE_ACC",
    "PIPELINE"
]
mergedDF = mergedDF.groupBy(groupbyCols).agg(F.sum("CellValue_new").alias("MEASURE_CODE_ACC_VALUE"))

# %%
mergedDF.show()
# Out:
# [Stage 5:>                                                          (0 + 1) / 1]
# +-----------+--------------------+-----+----------------+--------+----------------------+
# |  ChassisId|    CreationDateTime|LogId|MEASURE_CODE_ACC|PIPELINE|MEASURE_CODE_ACC_VALUE|
# +-----------+--------------------+-----+----------------+--------+----------------------+
# |H100E121013|2021-05-25 12:33:...| 1061| ENG_HOURS_TOTAL|  HAULER|             107930.35|
# |H100E121015|2021-05-30 19:07:...| 1061| TOTAL_FUEL_USED|  HAULER|              2802.326|
# |H100E121012|2021-05-29 23:51:...| 1061| ENG_HOURS_TOTAL|  HAULER|              109910.8|
# |H100E121013|2021-05-28 01:33:...| 1061| TOTAL_FUEL_USED|  HAULER|    2347.0910000000003|
# |H100E121012|2021-05-28 11:21:...| 1061| ENG_HOURS_TOTAL|  HAULER|              107522.6|
# |H100E121015|2021-05-24 23:43:...| 1061| TOTAL_FUEL_USED|  HAULER|              2366.595|
# |H100E121012|2021-05-31 01:21:...| 1061| TOTAL_FUEL_USED|  HAULER|              2287.869|
# |H100E121013|2021-05-30 18:03:...| 1061| ENG_HOURS_TOTAL|  HAULER|    127135.45000000001|
# |H100E121013|2021-05-29 18:03:...| 1061| TOTAL_FUEL_USED|  HAULER|    2456.9900000000002|
# |H100E121013|2021-05-26 18:03:...| 1061| TOTAL_FUEL_USED|  HAULER|              2265.434|
# |H100E121013|2021-05-27 18:03:...| 1061| TOTAL_FUEL_USED|  HAULER|              2320.085|
# |H100E121013|2021-05-28 05:33:...| 1061| ENG_HOURS_TOTAL|  HAULER|              118042.1|
# |H100E121013|2021-05-30 06:03:...| 1061| TOTAL_FUEL_USED|  HAULER|    2500.2010000000005|
# |H100E121013|2021-05-26 08:03:...| 1061| TOTAL_FUEL_USED|  HAULER|              2229.425|
# |H100E121013|2021-05-27 04:40:...| 1061| TOTAL_FUEL_USED|  HAULER|               2271.93|
# |H100E121012|2021-05-27 19:21:...| 1061| TOTAL_FUEL_USED|  HAULER|    2115.9170000000004|
# |H100E121015|2021-05-27 22:13:...| 1061| ENG_HOURS_TOTAL|  HAULER|    130456.90000000001|
# |H100E121013|2021-05-24 15:33:...| 1061| ENG_HOURS_TOTAL|  HAULER|             104150.35|
# |H100E121013|2021-05-30 12:33:...| 1061| ENG_HOURS_TOTAL|  HAULER|    126145.45000000001|
# |H100E121013|2021-05-26 09:33:...| 1061| ENG_HOURS_TOTAL|  HAULER|    111710.40000000001|
# +-----------+--------------------+-----+----------------+--------+----------------------+
# only showing top 20 rows

# %%
mergedDF.writeTo("local.db.merged_logs").create()

# %%
spark.sql("USE local.db")
spark.sql("SELECT * FROM merged_logs LIMIT 5").show()
# Out:
# +-----------+--------------------+-----+----------------+--------+----------------------+
# |  ChassisId|    CreationDateTime|LogId|MEASURE_CODE_ACC|PIPELINE|MEASURE_CODE_ACC_VALUE|
# +-----------+--------------------+-----+----------------+--------+----------------------+
# |H100E121013|2021-05-25 12:33:...| 1061| ENG_HOURS_TOTAL|  HAULER|             107930.35|
# |H100E121015|2021-05-30 19:07:...| 1061| TOTAL_FUEL_USED|  HAULER|              2802.326|
# |H100E121012|2021-05-29 23:51:...| 1061| ENG_HOURS_TOTAL|  HAULER|              109910.8|
# |H100E121013|2021-05-28 01:33:...| 1061| TOTAL_FUEL_USED|  HAULER|    2347.0910000000003|
# |H100E121012|2021-05-28 11:21:...| 1061| ENG_HOURS_TOTAL|  HAULER|              107522.6|
# +-----------+--------------------+-----+----------------+--------+----------------------+

# %%
spark.sql("""
    UPDATE local.db.merged_logs
    SET MEASURE_CODE_ACC_VALUE = 999.0
    WHERE ChassisId = 'H100E121013'
    AND MEASURE_CODE_ACC = 'ENG_HOURS_TOTAL'
""")
# Out:
# DataFrame[]

# %%
spark.sql("""
    DELETE FROM local.db.merged_logs
    WHERE LogId = 1061
    AND ChassisID = 'H100E121013'
""")
# Out:
# DataFrame[]
